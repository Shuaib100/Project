# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import glob

# initial parameters
epochs = 47
lr = 1e-3
batch_size = 64
img_dims = (96,96,3)

data = []
labels = []

# load image files from the dataset
image_files = [f for f in glob.glob(r'C:\Users\yaqub\Desktop\data science\ML project\Deep learning project\gender detection\New folder\Gender-Detection-master\gender_dataset_face' + "/**/*", recursive=True) if not os.path.isdir(f)]
random.shuffle(image_files)

# %%
# converting images to arrays and labelling the categories
for img in image_files:

    image = cv2.imread(img)
    
    image = cv2.resize(image, (img_dims[0],img_dims[1]))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2] # C:\Files\gender_dataset_face\woman\face_1162.jpg
    if label == "woman":
        label = 1
    else:
        label = 0
        
    labels.append([label]) # [[1], [0], [0], ...]

# %%
# pre-processing
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# split dataset for training and validation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2,
                                                  random_state=42)

trainY = to_categorical(trainY, num_classes=2) # [[1, 0], [0, 1], [0, 1], ...]
testY = to_categorical(testY, num_classes=2)

# augmenting datset 
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# define model
def build(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first": #Returns a string, either 'channels_first' or 'channels_last'
        inputShape = (depth, height, width)
        chanDim = 1
    
    # The axis that should be normalized, after a Conv2D layer with data_format="channels_first", 
    # set axis=1 in BatchNormalization.

    model.add(Conv2D(32, (3,3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# build model
model = build(width=img_dims[0], height=img_dims[1], depth=img_dims[2],
                            classes=2)

# compile the model
opt = Adam(lr=lr, decay=lr/epochs)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# train the model
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=batch_size),
                        validation_data=(testX,testY),
                        steps_per_epoch=len(trainX) // batch_size,
                        epochs=epochs, verbose=1)

# save the model to disk
model.save('gender_detection_copied.model')

# plot training/validation loss/accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0,N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,N), H.history["acc"], label="train_acc")
plt.plot(np.arange(0,N), H.history["val_acc"], label="val_acc")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")

# save plot to disk
plt.savefig('plot_copied.png')
# Out:
# C:\Users\yaqub\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# C:\Users\yaqub\AppData\Local\Temp\ipykernel_11676\210627445.py:76: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H = model.fit_generator(aug.flow(trainX, trainY, batch_size=batch_size),
# Epoch 1/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.7805 - accuracy: 0.7232 - val_loss: 0.7156 - val_accuracy: 0.5909
# Epoch 2/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.5140 - accuracy: 0.8170 - val_loss: 0.8565 - val_accuracy: 0.5022
# Epoch 3/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.4629 - accuracy: 0.8316 - val_loss: 1.8441 - val_accuracy: 0.5022
# Epoch 4/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.4019 - accuracy: 0.8394 - val_loss: 0.8492 - val_accuracy: 0.5065
# Epoch 5/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.3548 - accuracy: 0.8608 - val_loss: 0.7847 - val_accuracy: 0.5108
# Epoch 6/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.3215 - accuracy: 0.8770 - val_loss: 0.7951 - val_accuracy: 0.5649
# Epoch 7/100
# 28/28 [==============================] - 42s 1s/step - loss: 0.2717 - accuracy: 0.9017 - val_loss: 2.2449 - val_accuracy: 0.5022
# Epoch 8/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.2447 - accuracy: 0.9085 - val_loss: 0.6115 - val_accuracy: 0.7100
# Epoch 9/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.2544 - accuracy: 0.9040 - val_loss: 0.8856 - val_accuracy: 0.5801
# Epoch 10/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.2337 - accuracy: 0.9130 - val_loss: 0.3866 - val_accuracy: 0.8377
# Epoch 11/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.2160 - accuracy: 0.9242 - val_loss: 0.5940 - val_accuracy: 0.7965
# Epoch 12/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1857 - accuracy: 0.9270 - val_loss: 1.1375 - val_accuracy: 0.5844
# Epoch 13/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1927 - accuracy: 0.9253 - val_loss: 0.5340 - val_accuracy: 0.8139
# Epoch 14/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1786 - accuracy: 0.9377 - val_loss: 0.8792 - val_accuracy: 0.7229
# Epoch 15/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1833 - accuracy: 0.9276 - val_loss: 0.4612 - val_accuracy: 0.8398
# Epoch 16/100
# 28/28 [==============================] - 42s 1s/step - loss: 0.1953 - accuracy: 0.9253 - val_loss: 0.3226 - val_accuracy: 0.8918
# Epoch 17/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1409 - accuracy: 0.9500 - val_loss: 0.3109 - val_accuracy: 0.8983
# Epoch 18/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1222 - accuracy: 0.9506 - val_loss: 0.2272 - val_accuracy: 0.9286
# Epoch 19/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1448 - accuracy: 0.9450 - val_loss: 0.8360 - val_accuracy: 0.7684
# Epoch 20/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1610 - accuracy: 0.9416 - val_loss: 0.2115 - val_accuracy: 0.9351
# Epoch 21/100
# 28/28 [==============================] - 42s 1s/step - loss: 0.1316 - accuracy: 0.9495 - val_loss: 0.4171 - val_accuracy: 0.8701
# Epoch 22/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1197 - accuracy: 0.9551 - val_loss: 0.3237 - val_accuracy: 0.9004
# Epoch 23/100
# 28/28 [==============================] - 42s 1s/step - loss: 0.1141 - accuracy: 0.9601 - val_loss: 0.1549 - val_accuracy: 0.9502
# Epoch 24/100
# 28/28 [==============================] - 42s 1s/step - loss: 0.1095 - accuracy: 0.9562 - val_loss: 0.3620 - val_accuracy: 0.9004
# Epoch 25/100
# 28/28 [==============================] - 42s 1s/step - loss: 0.1050 - accuracy: 0.9534 - val_loss: 0.3002 - val_accuracy: 0.9221
# Epoch 26/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.1125 - accuracy: 0.9540 - val_loss: 0.2212 - val_accuracy: 0.9329
# Epoch 27/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.1158 - accuracy: 0.9534 - val_loss: 0.2444 - val_accuracy: 0.9199
# Epoch 28/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0951 - accuracy: 0.9657 - val_loss: 0.8978 - val_accuracy: 0.7662
# Epoch 29/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.1097 - accuracy: 0.9596 - val_loss: 0.1318 - val_accuracy: 0.9675
# Epoch 30/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0848 - accuracy: 0.9725 - val_loss: 0.3118 - val_accuracy: 0.9113
# Epoch 31/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0964 - accuracy: 0.9652 - val_loss: 1.0967 - val_accuracy: 0.7424
# Epoch 32/100
# 28/28 [==============================] - 43s 2s/step - loss: 0
100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0709 - accuracy: 0.9759 - val_loss: 0.1088 - val_accuracy: 0.9589
# Epoch 55/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0628 - accuracy: 0.9736 - val_loss: 0.0953 - val_accuracy: 0.9719
# Epoch 56/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0591 - accuracy: 0.9809 - val_loss: 0.1221 - val_accuracy: 0.9610
# Epoch 57/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0788 - accuracy: 0.9719 - val_loss: 0.0875 - val_accuracy: 0.9675
# Epoch 58/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0726 - accuracy: 0.9708 - val_loss: 0.1776 - val_accuracy: 0.9481
# Epoch 59/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0593 - accuracy: 0.9764 - val_loss: 0.0995 - val_accuracy: 0.9719
# Epoch 60/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0545 - accuracy: 0.9759 - val_loss: 0.1390 - val_accuracy: 0.9416
# Epoch 61/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0687 - accuracy: 0.9747 - val_loss: 0.1217 - val_accuracy: 0.9567
# Epoch 62/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0499 - accuracy: 0.9803 - val_loss: 0.3211 - val_accuracy: 0.9091
# Epoch 63/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0459 - accuracy: 0.9826 - val_loss: 0.0995 - val_accuracy: 0.9762
# Epoch 64/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0581 - accuracy: 0.9832 - val_loss: 0.2321 - val_accuracy: 0.9459
# Epoch 65/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0445 - accuracy: 0.9803 - val_loss: 0.1047 - val_accuracy: 0.9632
# Epoch 66/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0435 - accuracy: 0.9820 - val_loss: 0.1159 - val_accuracy: 0.9654
# Epoch 67/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0477 - accuracy: 0.9826 - val_loss: 0.2425 - val_accuracy: 0.9351
# Epoch 68/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0533 - accuracy: 0.9775 - val_loss: 0.1651 - val_accuracy: 0.9589
# Epoch 69/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0547 - accuracy: 0.9792 - val_loss: 0.2200 - val_accuracy: 0.9459
# Epoch 70/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0630 - accuracy: 0.9781 - val_loss: 0.2470 - val_accuracy: 0.9177
# Epoch 71/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0625 - accuracy: 0.9781 - val_loss: 0.1903 - val_accuracy: 0.9567
# Epoch 72/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0370 - accuracy: 0.9872 - val_loss: 0.0708 - val_accuracy: 0.9719
# Epoch 73/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0317 - accuracy: 0.9882 - val_loss: 0.0792 - val_accuracy: 0.9697
# Epoch 74/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0480 - accuracy: 0.9837 - val_loss: 0.0999 - val_accuracy: 0.9654
# Epoch 75/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0367 - accuracy: 0.9860 - val_loss: 0.1925 - val_accuracy: 0.9372
# Epoch 76/100
# 28/28 [==============================] - 41s 1s/step - loss: 0.0468 - accuracy: 0.9820 - val_loss: 0.0716 - val_accuracy: 0.9697
# Epoch 77/100
# 28/28 [==============================] - 41s 1s/step - loss: 0.0385 - accuracy: 0.9865 - val_loss: 0.0868 - val_accuracy: 0.9632
# Epoch 78/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.0417 - accuracy: 0.9854 - val_loss: 1.5039 - val_accuracy: 0.6818
# Epoch 79/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0532 - accuracy: 0.9792 - val_loss: 0.2690 - val_accuracy: 0.9394
# Epoch 80/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0502 - accuracy: 0.9809 - val_loss: 0.0936 - val_accuracy: 0.9654
# Epoch 81/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.0631 - accuracy: 0.9781 - val_loss: 0.4697 - val_accuracy: 0.9026
# Epoch 82/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0410 - accuracy: 0.9826 - val_loss: 0.1172 - val_accuracy: 0.9632
# Epoch 83/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.0474 - accuracy: 0.9832 - val_loss: 0.3932 - val_accuracy: 0.8745
# Epoch 84/100
# 28/28 [==============================] - 74s 3s/step - loss: 0.0474 - accuracy: 0.9809 - val_loss: 0.1155 - val_accuracy: 0.9610
# Epoch 85/100
# 28/28 [==============================] - 48s 2s/step - loss: 0.0533 - accuracy: 0.9820 - val_loss: 0.3033 - val_accuracy: 0.9372
# Epoch 86/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.0354 - accuracy: 0.9865 - val_loss: 2.2699 - val_accuracy: 0.6450
# Epoch 87/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0411 - accuracy: 0.9848 - val_loss: 0.1094 - val_accuracy: 0.9632
# Epoch 88/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.0391 - accuracy: 0.9871 - val_loss: 0.6790 - val_accuracy: 0.8853
# Epoch 89/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.0464 - accuracy: 0.9787 - val_loss: 0.1330 - val_accuracy: 0.9589
# Epoch 90/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0629 - accuracy: 0.9798 - val_loss: 0.1600 - val_accuracy: 0.9524
# Epoch 91/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0511 - accuracy: 0.9809 - val_loss: 0.2236 - val_accuracy: 0.9199
# Epoch 92/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0508 - accuracy: 0.9815 - val_loss: 0.1711 - val_accuracy: 0.9567
# Epoch 93/100
# 28/28 [==============================] - 43s 2s/step - loss: 0.0553 - accuracy: 0.9815 - val_loss: 0.4613 - val_accuracy: 0.8961
# Epoch 94/100
# 28/28 [==============================] - 48s 2s/step - loss: 0.0298 - accuracy: 0.9876 - val_loss: 0.1424 - val_accuracy: 0.9589
# Epoch 95/100
# 28/28 [==============================] - 54s 2s/step - loss: 0.0284 - accuracy: 0.9882 - val_loss: 0.1882 - val_accuracy: 0.9524
# Epoch 96/100
# 28/28 [==============================] - 42s 2s/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.2880 - val_accuracy: 0.9372
# Epoch 97/100
# 28/28 [==============================] - 47s 2s/step - loss: 0.0373 - accuracy: 0.9843 - val_loss: 0.1038 - val_accuracy: 0.9654
# Epoch 98/100
# 28/28 [==============================] - 45s 2s/step - loss: 0.0322 - accuracy: 0.9888 - val_loss: 0.1425 - val_accuracy: 0.9545
# Epoch 99/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0380 - accuracy: 0.9871 - val_loss: 0.3227 - val_accuracy: 0.9199
# Epoch 100/100
# 28/28 [==============================] - 44s 2s/step - loss: 0.0315 - accuracy: 0.9899 - val_loss: 0.0699 - val_accuracy: 0.9719
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: gender_detection_copied.model\assets
# INFO:tensorflow:Assets written to: gender_detection_copied.model\assets
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\style\core.py:127, in use(style)
#     126 try:
# --> 127     rc = rc_params_from_file(style, use_default_template=False)
#     128     _apply_style(rc)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:852, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     838 """
#     839 Construct a `RcParams` from file *fname*.
#     840
#    (...)
#     850     parameters specified in the file. (Useful for updating dicts.)
#     851 """
# --> 852 config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     854 if not use_default_template:
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:778, in _rc_params_in_file(fname, transform, fail_on_error)
#     777 rc_temp = {}
# --> 778 with _open_file_or_url(fname) as fd:
#     779     try:
#
# File ~\anaconda3\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:755, in _open_file_or_url(fname)
#     754     encoding = "utf-8"
# --> 755 with open(fname, encoding=encoding) as f:
#     756     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ggplot_copied'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Input In [3], in <cell line: 85>()
#      82 model.save('gender_detection_copied.model')
#      84 # plot training/validation loss/accuracy
# ---> 85 plt.style.use("ggplot_copied")
#      86 plt.figure()
#      87 N = epochs
#
# File ~\anaconda3\lib\site-packages\matplotlib\style\core.py:130, in use(style)
#     128     _apply_style(rc)
#     129 except IOError as err:
# --> 130     raise IOError(
#     131         "{!r} not found in the style library and input is not a "
#     132         "valid URL or path; see `style.available` for list of "
#     133         "available styles".format(style)) from err
#
# OSError: 'ggplot_copied' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
# plot training/validation loss/accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0,N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0,N), H.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")

# save plot to disk
plt.savefig('plot_copied.png')
